# %%
import matplotlib.pyplot as plt
import seaborn as sns

# G. Set Style and Create Visualization
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))

# Create a grouped bar chart (Bar Plot) to visualize Denial Rate
bar_plot = sns.barplot(
    x='derived_race', 
    y='Denial_Rate', 
    hue='DTI_Category', 
    data=scorecard_agg,  # <--- CORRECTED: Removed the quotes here!
    palette='viridis' 
)

# Add titles and labels for clarity
plt.title('Denial Rate by Race and Debt-to-Income (DTI) Category', fontsize=16)
plt.xlabel('Derived Race', fontsize=12)
plt.ylabel('Denial Rate (%)', fontsize=12)
plt.legend(title='DTI Category')
plt.xticks(rotation=45, ha='right') 
plt.tight_layout() 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 13
#       6 plt.figure(figsize=(10, 6))
#       8 # Create a grouped bar chart (Bar Plot) to visualize Denial Rate
#       9 bar_plot = sns.barplot(
#      10     x='derived_race',
#      11     y='Denial_Rate',
#      12     hue='DTI_Category',
# ---> 13     data=scorecard_agg,  # <--- CORRECTED: Removed the quotes here!
#      14     palette='viridis'
#      15 )
#      17 # Add titles and labels for clarity
#      18 plt.title('Denial Rate by Race and Debt-to-Income (DTI) Category', fontsize=16)
#
# NameError: name 'scorecard_agg' is not defined
